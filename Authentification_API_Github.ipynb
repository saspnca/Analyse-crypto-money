# %% [markdown]
# ## Authentification sur l'API Github

# %%
import requests

# %%
# création dictionnaire contenant le token
headers = {"Authorization":"token dd1305a7adaa767039a8d16dcaa0ba071c44e411"}

# %%
# Requête GET
response = requests.get("http://api.github.com/users/Pixnclickanalyse" , # codelikerod est le nom du profil à analyser (ex : Pixnclickanalyse)
                       headers=headers)

# %%
print(response.json())
# Out:
# {'login': 'Pixnclickanalyse', 'id': 22320818, 'node_id': 'MDQ6VXNlcjIyMzIwODE4', 'avatar_url': 'https://avatars0.githubusercontent.com/u/22320818?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Pixnclickanalyse', 'html_url': 'https://github.com/Pixnclickanalyse', 'followers_url': 'https://api.github.com/users/Pixnclickanalyse/followers', 'following_url': 'https://api.github.com/users/Pixnclickanalyse/following{/other_user}', 'gists_url': 'https://api.github.com/users/Pixnclickanalyse/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Pixnclickanalyse/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Pixnclickanalyse/subscriptions', 'organizations_url': 'https://api.github.com/users/Pixnclickanalyse/orgs', 'repos_url': 'https://api.github.com/users/Pixnclickanalyse/repos', 'events_url': 'https://api.github.com/users/Pixnclickanalyse/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Pixnclickanalyse/received_even
# ...

# %% [markdown]
# ## Pagination

# %%
params = {"per_page":50, "page":1}
response = requests.get("https://api.github.com/users/rakeshsukla53/starred",
                      headers=headers, params=params)
page1_repos = response.json()
print(page1_repos) # visualiser les 50 premiers repository de la page 1 liker (étoile) par l'utilisateur rakeshsukla53
# Out:
# [{'id': 65036318, 'node_id': 'MDEwOlJlcG9zaXRvcnk2NTAzNjMxOA==', 'name': 'app-inspector', 'full_name': 'macacajs/app-inspector', 'private': False, 'owner': {'login': 'macacajs', 'id': 12892132, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyODkyMTMy', 'avatar_url': 'https://avatars2.githubusercontent.com/u/12892132?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/macacajs', 'html_url': 'https://github.com/macacajs', 'followers_url': 'https://api.github.com/users/macacajs/followers', 'following_url': 'https://api.github.com/users/macacajs/following{/other_user}', 'gists_url': 'https://api.github.com/users/macacajs/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/macacajs/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/macacajs/subscriptions', 'organizations_url': 'https://api.github.com/users/macacajs/orgs', 'repos_url': 'https://api.github.com/users/macacajs/repos', 'events_url': 'https://api.github.com/users/macacajs/events{/privacy}', 're
# ...

# %% [markdown]
# ## Point d'accès User-Level

# %%
response = requests.get("https://api.github.com/user" ,
                       headers=headers)
user = response.json()
print(user)
# Out:
# {'login': 'Pixnclickanalyse', 'id': 22320818, 'node_id': 'MDQ6VXNlcjIyMzIwODE4', 'avatar_url': 'https://avatars0.githubusercontent.com/u/22320818?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Pixnclickanalyse', 'html_url': 'https://github.com/Pixnclickanalyse', 'followers_url': 'https://api.github.com/users/Pixnclickanalyse/followers', 'following_url': 'https://api.github.com/users/Pixnclickanalyse/following{/other_user}', 'gists_url': 'https://api.github.com/users/Pixnclickanalyse/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Pixnclickanalyse/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Pixnclickanalyse/subscriptions', 'organizations_url': 'https://api.github.com/users/Pixnclickanalyse/orgs', 'repos_url': 'https://api.github.com/users/Pixnclickanalyse/repos', 'events_url': 'https://api.github.com/users/Pixnclickanalyse/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Pixnclickanalyse/received_even
# ...

# %% [markdown]
# ## Requête POST

# %%
# payload = {"name":"test" , "description":"ceci est la description du repository"}
# requests.post("https://api.github.com/user/repos", json=payload)

# %%
payload = {"name":"api-scraping"}
response = requests.post("https://api.github.com/user/repos", json=payload,
                        headers=headers)
status = response.status_code
print(status)
# Out:
# 201

# %%
# On à créer un repository a partir d'ici dans github

# %% [markdown]
# ## Requête DELETE

# %%
# nous allons donc supprimez la repository qye nous avons crée juste avant

# %%
response = requests.delete("https://api.github.com/repos/Pixnclickanalyse/api-scraping",
                        headers=headers)
status = response.status_code
print(status)
# Out:
# 204
